# %% [markdown]
# ML assignment - Corona Case Study
#
# 1.	Write a Python program to display first 5 rows from COVID-19 dataset. Also print the dataset information and check the missing values
# 2.	Add Active Cases column in DataFrame
# 3.	Write a Python program to get the latest number of confirmed, deaths, recovered and active cases of Novel Coronavirus (COVID-19) Country wise
# 4.	Write a Python program to get the latest number of confirmed deaths and recovered people of Novel Coronavirus (COVID-19) cases Country/Region - Province/State wise
# 5.	Write a Python program to get the Chinese province wise cases of confirmed, deaths and recovered cases of Novel Coronavirus (COVID-19)
# 6.	Write a Python program to get the top 10 countries data (Last Update, Country/Region, Confirmed, Deaths, Recovered) of Novel Coronavirus (COVID-19)
# 7.	Write a Python program to list countries with all cases of Novel Coronavirus (COVID-19) recover

# %%
# importing required packages
import pandas as pd

# %%
# importing csv file as dataframe using pandas
df = pd.read_csv("Corona.csv")

# %%
df
# Out:
#      Unnamed: 0 Province/State                  Country/Region  \
# 0             0          Hubei                           China
# 1             1            NaN                           Italy
# 2             2            NaN                            Iran
# 3             3            NaN                           Spain
# 4             4            NaN                         Germany
# ..          ...            ...                             ...
# 271         271            NaN                        Guernsey
# 272         272            NaN                          Jersey
# 273         273            NaN                     Puerto Rico
# 274         274            NaN           Republic of the Congo
# 275         275            NaN  occupied Palestinian territory
#
#              Last Update  Confirmed  Deaths  Recovered  Latitude  Longitude
# 0    2020-03-17T11:53:10      67799    3111      56003   30.9756   112.2707
# ...

# %%
# displaying first 5 rows
df.head()
# Out:
#    Unnamed: 0 Province/State Country/Region          Last Update  Confirmed  \
# 0           0          Hubei          China  2020-03-17T11:53:10      67799
# 1           1            NaN          Italy  2020-03-17T18:33:02      31506
# 2           2            NaN           Iran  2020-03-17T15:13:09      16169
# 3           3            NaN          Spain  2020-03-17T20:53:02      11748
# 4           4            NaN        Germany  2020-03-17T18:53:02       9257
#
#    Deaths  Recovered  Latitude  Longitude
# 0    3111      56003   30.9756   112.2707
# 1    2503       2941   41.8719    12.5674
# 2     988       5389   32.4279    53.6880
# 3     533       1028   40.4637    -3.7492
# 4      24         67   51.1657    10.4515

# %%
# dataset information
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 276 entries, 0 to 275
# Data columns (total 9 columns):
# Unnamed: 0        276 non-null int64
# Province/State    126 non-null object
# Country/Region    276 non-null object
# Last Update       276 non-null object
# Confirmed         276 non-null int64
# Deaths            276 non-null int64
# Recovered         276 non-null int64
# Latitude          276 non-null float64
# Longitude         276 non-null float64
# dtypes: float64(2), int64(4), object(3)
# memory usage: 19.5+ KB

# %%
# checking for missing values
df.isnull()
# Out:
#      Unnamed: 0  Province/State  Country/Region  Last Update  Confirmed  \
# 0         False           False           False        False      False
# 1         False            True           False        False      False
# 2         False            True           False        False      False
# 3         False            True           False        False      False
# 4         False            True           False        False      False
# ..          ...             ...             ...          ...        ...
# 271       False            True           False        False      False
# 272       False            True           False        False      False
# 273       False            True           False        False      False
# 274       False            True           False        False      False
# 275       False            True           False        False      False
#
#      Deaths  Recovered  Latitude  Longitude
# 0     False      False     False      False
# ...

# %%
# inserting the active cases column in df

df['Active']= df['Confirmed']-(df['Deaths'] + df['Recovered'])
df.head(10)
# Out:
#    Unnamed: 0  Province/State  Country/Region          Last Update  Confirmed  \
# 0           0           Hubei           China  2020-03-17T11:53:10      67799
# 1           1             NaN           Italy  2020-03-17T18:33:02      31506
# 2           2             NaN            Iran  2020-03-17T15:13:09      16169
# 3           3             NaN           Spain  2020-03-17T20:53:02      11748
# 4           4             NaN         Germany  2020-03-17T18:53:02       9257
# 5           5             NaN    Korea, South  2020-03-17T10:33:03       8320
# 6           6          France          France  2020-03-17T19:13:08       7652
# 7           7             NaN     Switzerland  2020-03-17T16:33:04       2700
# 8           8  United Kingdom  United Kingdom  2020-03-17T15:13:09       1950
# 9           9        New York              US  2020-03-17T22:53:03       1706
#
#    Deaths  Recovered  Latitude  Longitude  Active
# 0    3111      56003   30.9756   112.2707    8685
# ...

# %%
# latest number of confirmed, deaths, recovered and active cases country wise

df.groupby(['Country/Region'])['Confirmed','Deaths','Recovered','Active'].sum()
# Out:
#                                 Confirmed  Deaths  Recovered  Active
# Country/Region
# Afghanistan                            22       0          1      21
# Albania                                55       1          0      54
# Algeria                                60       4         12      44
# Andorra                                39       0          1      38
# Antigua and Barbuda                     1       0          0       1
# ...                                   ...     ...        ...     ...
# Uruguay                                29       0          0      29
# Uzbekistan                             10       0          0      10
# Venezuela                              33       0          0      33
# Vietnam                                66       0         16      50
# occupied Palestinian territory          0       0          0       0
#
# [159 rows x 4 columns]

# %%
# latest number of confirmed, deaths and recovered cases Country/Region - Province/State wise

df.groupby(["Country/Region","Province/State"]) ["Confirmed","Recovered","Deaths"].sum()
# Out:
#                                              Confirmed  Recovered  Deaths
# Country/Region Province/State
# Australia      Australian Capital Territory          2          0       0
#                From Diamond Princess                 0          0       0
#                New South Wales                     210          4       4
#                Northern Territory                    1          0       0
#                Queensland                           78          8       0
# ...                                                ...        ...     ...
# US             Wyoming                              11          0       0
# United Kingdom Cayman Islands                        1          0       1
#                Channel Islands                       6          0       0
#                Gibraltar                             3          1       0
#                United Kingdom                     1950         52      55
#
# [126 rows x 3 columns]

# %%
# Chinese province wise cases 

df.iloc[:,[1,2,4,6,7]][df['Country/Region'] == "China"]
# Out:
#      Province/State Country/Region  Confirmed  Deaths  Recovered
# 0             Hubei          China    67799.0  3111.0    56003.0
# 12        Guangdong          China     1364.0     8.0     1307.0
# 14            Henan          China     1273.0    22.0     1250.0
# 16         Zhejiang          China     1232.0     1.0     1216.0
# 19            Hunan          China     1018.0     4.0     1014.0
# 20            Anhui          China      990.0     6.0      984.0
# 22          Jiangxi          China      935.0     1.0      934.0
# 24         Shandong          China      761.0     7.0      746.0
# 28          Jiangsu          China      631.0     0.0      631.0
# 29        Chongqing          China      576.0     6.0      570.0
# 30          Sichuan          China      540.0     3.0      520.0
# 31     Heilongjiang          China      482.0    13.0      456.0
# 32          Beijing          China      456.0     8.0      369.0
# ...

# %%
# top 10 countries of coronavirus data

country_cases = df.groupby('Country/Region')[['Confirmed','Recovered','Deaths']].sum()
country_cases.sort_values(by=['Confirmed'],ascending=False).head(10)
# Out:
#                 Confirmed  Recovered  Deaths
# Country/Region
# China               81058      68798    3230
# Italy               31506       2941    2503
# Iran                16169       5389     988
# Spain               11748       1028     533
# Germany              9257         67      24
# Korea, South         8320       1407      81
# France               7683         12     148
# US                   6421         17     108
# Switzerland          2700          4      27
# United Kingdom       1960         53      56

# %%
# countries where all cases of corona recovered

country_rec = df.groupby('Country/Region') [['Confirmed','Recovered']].sum() 
country_rec = country_rec[country_rec['Confirmed'] == country_rec['Recovered']]
country_rec = country_rec[country_rec["Confirmed"]>0]
country_rec
# Out:
#                 Confirmed  Recovered
# Country/Region
# Nepal                   1          1
